# %% [markdown]
# ### Imports

# %%
from AugModel import Augmenter
from PIL import Image

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Model initialization

# %%
model = Augmenter()
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# Device set to use cuda
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# ### Examples of working

# %%
from PIL import Image
image = Image.open(
    "examples/bread.png")
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1021x1024>

# %%
result, prompt, threshold, bbox = model(
    image=image,
    ddim_steps=50,
    guidance_scale=30,
    seed=42
)

print(f"Prompt: {prompt}, threshold: {threshold}, bbox: {bbox}")
result
# Out:
# 0: 640x640 3 cakes, 7.3ms
# Speed: 3.0ms preprocess, 7.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#   0%|          | 0/50 [00:00<?, ?it/s]
# Prompt: A golden pizza crust, crisp edges, melted cheese, red sauce, fresh basil, and pepperoni slices on a white plate with a croissant.
# 4k, ultra HD, highly detailed, realistic lighting., threshold: 0.28173828125, bbox: [262   8 792 496]
# <PIL.Image.Image image mode=RGB size=1024x1024>
